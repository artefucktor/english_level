# %%
import pandas as pd
import numpy as np
import os
import re
import warnings

import seaborn as sns
import matplotlib.pyplot as plt

try:
    from pypdf import PdfReader
except:
    # !pip install pypdf
    from pypdf import PdfReader

try:
    import spacy
except:
    # !pip install spacy
    # !python -m spacy download en
    import spacy

try:
    import chardet
except:
    # !pip install chardet
    import chardet
    
    
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, mean_squared_error, f1_score

import xgboost
import catboost

# %%
warnings.filterwarnings("ignore")
plt.style.use('ggplot')
nlp = spacy.load("en_core_web_sm")

SCORES_PATH    = 'English_level/English_scores'
SUBTITLES_PATH = 'English_level/English_scores/Subtitles_all'
OXFORD_PATH    = 'English_level/Oxford_CEFR_level'

ENGLISH_LEVELS = ['A1', 'A2', 'B1', 'B2', 'C1']

RANDOM_STATE = 7

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## The Oxford core by CEFR level

# %%
def process_pdf(content):
    
    current_level = ''
    words_by_level = {key:[] for key in ENGLISH_LEVELS}
    
    for line in content:
        line = line.strip()

        if 'Oxford' in line or 'English' in line:
            pass
        
        elif line in ENGLISH_LEVELS:
            level = line
            
        elif ' ' in line:
            line = re.sub(r'\d|,', '', line.lower())   # remove digits and commas and transform to lowercase
            words_by_level[level] += [line.split()[0]] #get the first occurency in line as word
            
        else:
            pass
    
    return words_by_level


content = []
oxford_words = pd.DataFrame(columns=['word', 'level', 'source', 'type'])

# load all pdfs
for dirname, _, filenames in os.walk(OXFORD_PATH):
    for filename in filenames:
        print(filename)
        reader = PdfReader(f'{OXFORD_PATH}/{filename}')
        for page in reader.pages:
            content += page.extract_text().splitlines()
        processed = process_pdf(content)
        for level in processed:
            dict_type = 'us' if 'American' in filename else 'uk'
            oxford_words = pd.concat([oxford_words,
                                      pd.DataFrame({'word'   : processed[level],
                                                    'level'  : level,
                                                    'source' : filename,
                                                    'type'   : dict_type
                                                   })
                                     ])

# sort words and keep unique with higher levels
oxford_words = oxford_words.sort_values(by=['word', 'level'], ascending=True)
oxford_words = oxford_words.drop_duplicates(subset=['word'], keep='last')

# после сортировки и удаления дубликатов остался только американский инглиш
# похоже там все уровни слов считаются выше

oxford_words.groupby('level') \
            .agg({'word':'count', 'source': 'unique'}) \
            .style.format({'word':'{:,.0f} слов'})
# Out:
# American_Oxford_3000_by_CEFR_level.pdf
# The_Oxford_3000_by_CEFR_level.pdf
# The_Oxford_5000_by_CEFR_level.pdf
# American_Oxford_5000_by_CEFR_level.pdf
# <style type="text/css">
# </style>
# <table id="T_ad86c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad86c_level0_col0" class="col_heading level0 col0" >word</th>
#       <th id="T_ad86c_level0_col1" class="col_heading level0 col1" >source</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad86c_level0_row0" class="row_heading level0 row0" >A1</th>
#       <td id="T_ad86c_row0_col0" class="data row0 col0" >735 слов</td>
#       <td id="T_ad86c_row0_col1" class="data row0 col1" >['American_Oxford_5000_by_CEFR_level.pdf']</td>
#     </tr>
#     <tr>
#       <th id="T_ad86c_level0_row1" class="row_heading level0 row1" >A2</th>
#       <td id="T_ad86c_row1_col0" class="data row1 col0" >747 слов</td>
#       <td id="T_ad86c_row1_col1" class="data row1 col1" >['American_Oxford_5000_by_CEFR_level.pdf']</td>
#     </tr>
#     <tr>
#       <th id="T_ad86c_level0_row2" class="row_heading level0 row2" >B1</th>
#       <td id="T_ad86c_row2_col0" class="data row2 col0" >758 слов</td>
#       <td id="T_ad86c_row2_col1" class="data row2 col1" >['American_Oxford_5000_by_CEFR_level.pdf']</td>
#     </tr>
#     <tr>
#       <th id="T_ad86c_level0_row3" class="row_heading level0 row3" >B2</th>
#       <td id="T_ad86c_row3_col0" class="data row3 col0" >1,446 слов</td>
#       <td id="T_ad86c_row3_col1" class="data row3 col1" >['American_Oxford_5000_by_CEFR_level.pdf']</td>
#     </tr>
#     <tr>
#       <th id="T_ad86c_level0_row4" class="row_heading level0 row4" >C1</th>
#       <td id="T_ad86c_row4_col0" class="data row4 col0" >1,198 слов</td>
#       <td id="T_ad86c_row4_col1" class="data row4 col1" >['American_Oxford_5000_by_CEFR_level.pdf']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Subtitles .srt

# %%
# parse and clean subtitles
def clean_text(content):
    text = []
    for line in content.splitlines():                        
        if re.search(r'[A-Za-z]',line):                      # get non empty lines with words
            line = line.lower()                              # transform to lowercase
            line = re.sub(r'\<[^<]+?\>', ' ', line)          # remove html tags
            line = re.sub(r'(\(.+\))|(\[.+\])', ' ', line)   # remove actions in parenthesis
            line = re.sub(r'([\w#\s]+\:)', ' ', line)        # remove speaker in dialogs
            line = re.sub(r'(?<=\w)\'(?=\w)', '', line)      # glue apostroph inside words
            line = re.sub(r'[^a-z]', ' ', line)              # remove non-word symbols
#             line = re.sub(r'\b\w{1,2}\b', '', line)          # remove single and two symbol sequences
            line = re.sub(r'\s\s+', ' ', line).strip()       # remove extra spaces longer than single
            if len(line)>0:
                text.append(line)
    return ' '.join(text)


# process file
def process_srt(dirname, filename):
    global count
    if not filename.endswith('.srt'):                        # skip non srt files
        print('посторонний файл', filename)
        return False
    fullpath = os.path.join(dirname,filename)
    try:
        file = open(fullpath, 'rb')
        content = file.read()
        file.close()
        encoding = chardet.detect(content)['encoding']      # detect encoding and convert
#         print(encoding)
        content = content.decode(encoding)
    except:
        print('не прочиталось', filename)
        return False
    return clean_text(content)                               # clean text and return

movies = pd.DataFrame(columns=['movie', 'filename', 'content', 'level', 'lemmas'] + ENGLISH_LEVELS + \
                              [l+'uk' for l in ENGLISH_LEVELS] + \
                              [l+'us' for l in ENGLISH_LEVELS] + \
                              [l+'ratio' for l in ENGLISH_LEVELS]
                     )

# recursive walk through dirs
for dirname, _, filenames in os.walk(SUBTITLES_PATH):
    for filename in filenames:
        level = dirname.split('/')[-1]                       # get level name from dir
        subs = process_srt(dirname, filename)                # process file
        if subs:                                             # add movie to dataframe
            movies.loc[len(movies)] = \
                {'filename': filename.replace('.srt', ''),
                 'content' : subs,
                 'level'   : level
                }

movies.head()
# Out:
# посторонний файл .DS_Store
# посторонний файл .DS_Store
#    movie                                           filename  \
# 0    NaN            Crown, The S01E01 - Wolferton Splash.en
# 1    NaN                            Suits.Episode 1- Denial
# 2    NaN  Crazy4TV.com - Suits.S06E06.720p.BluRay.x265.H...
# 3    NaN                      Suits.S02E08.HDTV.x264-EVOLVE
# 4    NaN  Virgin.River.S01E07.INTERNAL.720p.WEB.x264-STRiFE
#
#                                              content level  lemmas  A1  A2  \
# 0  in seeking his british nationalization his roy...    B2     NaN NaN NaN
# 1  youre the most amazing woman i have ever met a...    B2     NaN NaN NaN
# 2  ive been after sutter for three years now this...    B2     NaN NaN NaN
# 3  youre late nope seconds early good learning to...    B2     NaN NaN NaN
# 4  are you sure i cant convince you to stay no yo...    B2     NaN NaN NaN
#
#    B1  B2  C1  ...  A1us  A2us  B1us  B2us  C1us  A1ratio  A2ratio  B1ratio  \
# 0 NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN      NaN      NaN      NaN
# 1 NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN      NaN      NaN      NaN
# 2 NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN      NaN      NaN      NaN
# 3 NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN      NaN      NaN      NaN
# 4 NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN      NaN      NaN      NaN
#
#    B2ratio  C1ratio
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Excel labels processing

# %%
movie_labels = pd.read_excel(f'{SCORES_PATH}/movies_labels.xlsx', index_col='id')
movie_labels.info()
movie_labels.columns = ['movie', 'level']
print('\nДубликаты полные', movie_labels.duplicated().sum())
print('Дубликаты в названиях фильмов', movie_labels.movie.duplicated().sum())
movie_labels = movie_labels.drop_duplicates()
movie_labels
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241 entries, 0 to 240
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Movie   241 non-null    object
#  1   Level   241 non-null    object
# dtypes: object(2)
# memory usage: 5.6+ KB
#
# Дубликаты полные 2
# Дубликаты в названиях фильмов 4
#                                 movie   level
# id
# 0           10_Cloverfield_lane(2016)      B1
# 1    10_things_I_hate_about_you(1999)      B1
# 2                A_knights_tale(2001)      B2
# 3                A_star_is_born(2018)      B2
# 4                       Aladdin(1992)  A2/A2+
# ..                                ...     ...
# 236                     Matilda(2022)      C1
# 237                      Bullet train      B1
# 238            Thor: love and thunder      B2
# 239                         Lightyear      B2
# 240                        The Grinch      B1
#
# [239 rows x 2 columns]

# %%
# correct some mistakes in movies names
movie_labels.movie = movie_labels.movie.str.replace('.srt', '', regex=False)
movie_labels.loc[movie_labels.movie == 'Up (2009)', 'movie'] = 'Up(2009)'
movie_labels.loc[movie_labels.movie == 'The Grinch', 'movie'] = 'The.Grinch'

# удалим из level лишние символы, разделители оставим пробел
# из мультиуровней выберем наименьший
movie_labels.level = movie_labels.level \
                                 .str.replace(',', '', regex=False) \
                                 .str.replace('+', '', regex=False) \
                                 .str.replace('/', ' ', regex=False) \
                                 .str.split().transform(lambda x: min(x))

movie_labels.groupby('level').count().style.format({'movie':'{:.0f} фильмов'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_57234">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57234_level0_col0" class="col_heading level0 col0" >movie</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >level</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57234_level0_row0" class="row_heading level0 row0" >A2</th>
#       <td id="T_57234_row0_col0" class="data row0 col0" >37 фильмов</td>
#     </tr>
#     <tr>
#       <th id="T_57234_level0_row1" class="row_heading level0 row1" >B1</th>
#       <td id="T_57234_row1_col0" class="data row1 col0" >61 фильмов</td>
#     </tr>
#     <tr>
#       <th id="T_57234_level0_row2" class="row_heading level0 row2" >B2</th>
#       <td id="T_57234_row2_col0" class="data row2 col0" >101 фильмов</td>
#     </tr>
#     <tr>
#       <th id="T_57234_level0_row3" class="row_heading level0 row3" >C1</th>
#       <td id="T_57234_row3_col0" class="data row3 col0" >40 фильмов</td>
#     </tr>
#   </tbody>
# </table>

# %%
# excel processing
for row in movie_labels.itertuples():

    n = movies.loc[movies.filename.str.contains(row.movie, regex=False)].shape[0]

    if n == 0:
        print('не найден текст', row.movie)

    elif n == 1:
        selected_movie_level = movies.loc[
            movies.filename.str.contains(row.movie, regex=False), 'level'].values[0]

        if selected_movie_level == 'Subtitles':         # replace Subtitles with excel level
             movies.loc[
                 movies.filename.str.contains(row.movie, regex=False), 'level'] = row.level

        elif selected_movie_level != row.level:          # replace with min current level or excel
             movies.loc[
                 movies.filename.str.contains(row.movie, regex=False), 'level'
             ] = min(selected_movie_level, row.level)

    else:
        print('не единственный текст', row.movie)
            
# movies
# Out:
# не найден текст The Secret Life of Pets.en
# не найден текст Glass Onion
# не найден текст Matilda(2022)
# не найден текст Bullet train
# не найден текст Thor: love and thunder
# не найден текст Lightyear

# %% [markdown]
# ## Lemmatization

# %%
# %%time
# movies content lemmatization
movies['lemmas'] = movies.content.transform(lambda text: ' '.join([w.lemma_ for w in nlp(text)]))
# Out:
# CPU times: user 8min 53s, sys: 15.8 s, total: 9min 9s
# Wall time: 9min 12s

# %% [markdown]
# ## Feature engineering

# %%
# oxford words in movies lemmas
def count_words_by_level(row):

    row_lemmas = row.lemmas.split()
    
    total_score = oxford_words.loc[oxford_words.word.isin(row_lemmas)] \
                              .groupby('level').word.count().to_dict()
    
#     british_score = oxford_words.loc[
#         (oxford_words.type == 'uk') & \
#         (oxford_words.word.isin(row_lemmas))
#     ].groupby('level').word.count().to_dict()

#     american_score = oxford_words.loc[
#         (oxford_words.type == 'us') & \
#         (oxford_words.word.isin(row_lemmas))
#     ].groupby('level').word.count().to_dict()

#     total_score.update({k+'en':v for k,v in british_score.items()})
#     total_score.update({k+'us':v for k,v in american_score.items()})
    
    row[total_score.keys()] = total_score

    return row

movies = movies.apply(count_words_by_level, axis=1)

# %%
# %%time
# coverage of oxford dict and ratio of coverage        
def coverage_oxford(row):
    
    global l, oxford_equal, oxford_less, oxford_more
    row_lemmas = set(row.lemmas.split())
    
    cover_col = 'coverage_' + l
    ratio_col = 'coverage_' + l + 'ratio'
    
    cover_less = 'coverage_less_equal_' + l
    ratio_less = 'coverage_less_equal_' + l + 'ratio'

    cover_more = 'coverage_more_than_' + l
    ratio_more = 'coverage_more_than_' + l + 'ratio'
    
    # покрытие словаря в фильме (по уровням)
    row[cover_col] = sum(lemma in oxford_equal for lemma in row_lemmas)
    row[ratio_col] = row[cover_col] / len(oxford_equal)

    # покрытие словаря суммарно по уровням до заданного включительно
    row[cover_less] = sum(lemma in oxford_less for lemma in row_lemmas)
    row[ratio_less] = row[cover_less] / len(oxford_less)

    # покрытие словаря выше заданного уровня
    len_oxford_more = len(oxford_more)
    if len_oxford_more>0:
        row[cover_more] = sum(lemma in oxford_more for lemma in row_lemmas)
        row[ratio_more] = row[cover_more] / len(oxford_more)
    else:
        row[cover_more], row[ratio_more] = 0, 0

    return row

for l in ENGLISH_LEVELS:
    oxford_equal = oxford_words[oxford_words.level==l].word.values
    oxford_less  = oxford_words[oxford_words.level<=l].word.values
    oxford_more  = oxford_words[oxford_words.level>l].word.values
    movies = movies.apply(coverage_oxford, axis=1)

# %%
# total lemmas count
# and unique lemmas count
# and unique ratio
movies['lemmas_count']  = movies.lemmas.transform(lambda x: len(x.split()))
movies['lemmas_unique'] = movies.lemmas.transform(lambda x: len(set(x.split())))
movies['lemmas_unique_ratio'] = movies.lemmas_unique / movies.lemmas_count

# %%
# ratio oxford words in content
for l in ENGLISH_LEVELS:
    movies[l+'ratio'] = movies[l]/movies.lemmas_unique

# %%
# count words by length
# and ratio to total count
for i in range(1,10):
    equal_col = 'equal_'+str(i)
    more_col  = 'more_than_'+str(i)
    less_col  = 'less_than_'+str(i)
    
    movies[equal_col] = movies.lemmas.transform(lambda x: sum(len(word)==i for word in x.split()))
    movies[more_col]  = movies.lemmas.transform(lambda x: sum(len(word)>i for word in x.split()))
    movies[less_col]  = movies.lemmas.transform(lambda x: sum(len(word)<i for word in x.split()))
    
    movies[equal_col + 'ratio'] = movies[equal_col] / movies.lemmas_count
    movies[more_col + 'ratio']  = movies[more_col] / movies.lemmas_count
    movies[less_col + 'ratio']  = movies[less_col] / movies.lemmas_count

# %%
# export data movies to csv
movies['target'] = movies.level.replace({'A1':1, 'A2':2, 'B1':3, 'B2':4, 'C1':5, 'C2':6})
movies = movies.fillna(0)
movies = movies[movies.level!='Subtitles']
movies.to_csv('movies_df.csv', index=False)

try:
    os.system('say "data processing completed"')
except:
    pass

# %% [markdown]
# # MODELS TEST

# %%
movies = pd.read_csv('movies_df.csv')

# %%
text = 'lemmas'

lemmas_num = ['lemmas_count', 'lemmas_unique', 'lemmas_unique_ratio']

levels_ratio = [l+'ratio' for l in ENGLISH_LEVELS]
# levels_us    = [l+'us' for l in ENGLISH_LEVELS]
# levels_uk    = [l+'uk' for l in ENGLISH_LEVELS]

length_equal = ['equal_'+str(i) for i in range(1,10)]
length_more  = ['more_than_'+str(i) for i in range(1,10)]
length_less  = ['less_than_'+str(i) for i in range(1,10)]

equal_ratio = [c+'ratio' for c in length_equal]
more_ratio  = [c+'ratio' for c in length_more]
less_ratio  = [c+'ratio' for c in length_less]

oxford_cover = ['coverage_' + l for l in ENGLISH_LEVELS]
oxford_ratio = ['coverage_' + l + 'ratio' for l in ENGLISH_LEVELS]
    
oxford_cover_less= ['coverage_less_equal_' + l for l in ENGLISH_LEVELS]
oxford_ratio_less= ['coverage_less_equal_' + l + 'ratio' for l in ENGLISH_LEVELS]

oxford_cover_more= ['coverage_more_than_' + l for l in ENGLISH_LEVELS]
oxford_ratio_more= ['coverage_more_than_' + l + 'ratio' for l in ENGLISH_LEVELS]


# num_us = lemmas_num + levels_us
# num_en = lemmas_num + levels_uk

num = [*lemmas_num,
       *levels_ratio,
#        *length_equal,
#        *length_more,
#        *length_less,
       *equal_ratio,
       *more_ratio,
       *less_ratio,
#        *oxford_cover,
       *oxford_ratio,
#        *oxford_cover_less,
       *oxford_ratio_less,
#        *oxford_cover_more,
       *oxford_ratio_more
      ]

target = 'level'

# %%
encoder = OrdinalEncoder()

X_train, X_test, y_train, y_test = train_test_split(movies, 
                                                    movies.target,
#                                                     encoder.fit_transform(movies[[target]]), 
                                                    stratify=movies[[target]],
                                                    random_state=RANDOM_STATE,
                                                    test_size=0.3
                                                   )

# %%
# vectorizer = TfidfVectorizer()
vectorizer = CountVectorizer()
scaler     = StandardScaler()

preprocessor = ColumnTransformer([
    ('num', scaler, more_ratio),
    ('txt', vectorizer,  text)
], remainder='drop')

# %% [markdown]
# ## Regressor

# %%
# %%time

params = {
#     'pre__txt__stop_words'  : [None, 'english'],
#     'pre__txt__ngram_range' : [(1,1), (1,2), (1,3)],
#     'pre__txt__max_features': [None, 1000],
#     'pre__txt__min_df'      : [1, 10, 100],
    'reg__learning_rate'    : [0.05, 0.1, 0.2],
    'reg__n_estimators'     : [50, 100, 200],
    'reg__max_depth'        : [3, 5, 7],
    'reg__min_child_weight' : [1, 3, 5],
    'reg__gamma'            : [0, 0.1, 0.5, 1],
    'reg__subsample'        : [0.6, 0.8, 1.0],
    'reg__colsample_bytree' : [0.6, 0.8, 1.0],
    'reg__reg_alpha'        : [0, 0.1, 1],
    'reg__reg_lambda'       : [0, 0.1, 1],
    'reg__gamma'            : [0, 1, 5]
}

regressor = xgboost.XGBRegressor(random_state=RANDOM_STATE)

pipeline = Pipeline(steps=[
    ('pre', preprocessor),
    ('reg', regressor)
])

rc = RandomizedSearchCV(pipeline,
                        param_distributions=params,
                        scoring='neg_mean_squared_error',
                        error_score='raise',
                        random_state=RANDOM_STATE,
                        n_jobs=-1
                       )

rc.fit(X_train,y_train)

try:
    os.system('say "Model training completed"')
except:
    pass

-rc.best_score_
# Out:
# CPU times: user 3.05 s, sys: 1.07 s, total: 4.12 s
# Wall time: 25.4 s
# 0.40931243274889384

# %%
from sklearn.inspection import permutation_importance
permut = permutation_importance(rc, X_test, y_test, scoring='neg_mean_squared_error',n_jobs=-1,random_state=7)

# %%
feature_names = rc.best_estimator_[0].get_feature_names_out()
for i in permut.importances_mean.argsort()[::-1]:
     if permut.importances_mean[i] - 2 * permut.importances_std[i] > 0:
        print(f"{feature_names[i]:<8} "
              f"{permut.importances_mean[i]:.3f} "
              f"+/- {permut.importances_std[i]:.3f} ")
# Out:
# num__more_than_2ratio 0.087 +/- 0.016
# num__less_than_9 0.042 +/- 0.015
# num__equal_8ratio 0.024 +/- 0.010
# num__less_than_3 0.021 +/- 0.010
# num__more_than_2 0.009 +/- 0.004
# num__more_than_5ratio 0.007 +/- 0.003
# num__coverage_more_than_A2ratio 0.004 +/- 0.001
# num__more_than_3ratio 0.003 +/- 0.001
# num__more_than_7ratio 0.003 +/- 0.001
# num__more_than_6ratio 0.003 +/- 0.001
# num__coverage_less_equal_B1ratio 0.002 +/- 0.001

# %%
f1_score(y_test,round(rc.predict(X_test)))

# %%
rc.best_params_
# 0.4176481932162507
# {'reg__subsample': 1.0,
#  'reg__reg_lambda': 1,
#  'reg__reg_alpha': 1,
#  'reg__n_estimators': 200,
#  'reg__min_child_weight': 1,
#  'reg__max_depth': 3,
#  'reg__learning_rate': 0.1,
#  'reg__gamma': 0,
#  'reg__colsample_bytree': 0.6,
#  'pre__txt__stop_words': None,
#  'pre__txt__ngram_range': (1, 3),
#  'pre__txt__min_df': 100,
#  'pre__txt__max_features': None}
# Out:
# {'reg__subsample': 1.0,
#  'reg__reg_lambda': 1,
#  'reg__reg_alpha': 1,
#  'reg__n_estimators': 200,
#  'reg__min_child_weight': 1,
#  'reg__max_depth': 3,
#  'reg__learning_rate': 0.1,
#  'reg__gamma': 0,
#  'reg__colsample_bytree': 0.6,
#  'pre__txt__stop_words': None,
#  'pre__txt__ngram_range': (1, 3),
#  'pre__txt__min_df': 100,
#  'pre__txt__max_features': None}

# %%
tmp = movies.corrwith(movies.target)[:-1].sort_values()

# %%
tmp[tmp.notna()].tail(5)
# Out:
# B2ratio             0.199882
# less_than_3ratio    0.239173
# equal_7ratio        0.250607
# B1ratio             0.260626
# equal_2ratio        0.289288
# dtype: float64

# %%
tmp[tmp.notna()].head(5)
# Out:
# equal_5ratio       -0.361883
# equal_4ratio       -0.260176
# more_than_2ratio   -0.239173
# equal_5            -0.198538
# more_than_3ratio   -0.169937
# dtype: float64

# %%
movies.corrwith(movies.target)[:-1].round(2).sort_values(ascending=False).plot()
plt.xticks(rotation=90)
plt.show()

# %%
# Out:
# more_than_2                  -0.12
# equal_6                      -0.12
# more_than_3                  -0.12
# lemmas_unique                -0.13
# equal_4                      -0.13
# more_than_1ratio             -0.13
# A1                           -0.13
# coverage_A2ratio             -0.15
# coverage_A2                  -0.15
# less_than_7ratio             -0.16
# more_than_3ratio             -0.17
# equal_5                      -0.20
# more_than_2ratio             -0.24
# equal_4ratio                 -0.26
# equal_5ratio                 -0.36
# movie                          NaN
# less_than_1                    NaN
# less_than_1ratio               NaN
# coverage_more_than_C1          NaN
# coverage_more_than_C1ratio     NaN
# dtype: float64

# %%
movies[['target']+[col for col in movies if col.endswith('ratio')]].corr().round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e45ec_row0_col0, #T_e45ec_row1_col1, #T_e45ec_row2_col2, #T_e45ec_row3_col3, #T_e45ec_row4_col4, #T_e45ec_row5_col5, #T_e45ec_row6_col6, #T_e45ec_row7_col7, #T_e45ec_row7_col12, #T_e45ec_row8_col8, #T_e45ec_row10_col10, #T_e45ec_row11_col11, #T_e45ec_row12_col7, #T_e45ec_row12_col12, #T_e45ec_row13_col13, #T_e45ec_row14_col14, #T_e45ec_row15_col15, #T_e45ec_row16_col16, #T_e45ec_row17_col17, #T_e45ec_row18_col18, #T_e45ec_row19_col19, #T_e45ec_row20_col20, #T_e45ec_row21_col21, #T_e45ec_row22_col22, #T_e45ec_row23_col23, #T_e45ec_row24_col24, #T_e45ec_row25_col25, #T_e45ec_row26_col26, #T_e45ec_row27_col27, #T_e45ec_row28_col28, #T_e45ec_row29_col29, #T_e45ec_row30_col30, #T_e45ec_row31_col31, #T_e45ec_row32_col32, #T_e45ec_row33_col33, #T_e45ec_row34_col34, #T_e45ec_row34_col39, #T_e45ec_row34_col41, #T_e45ec_row34_col43, #T_e45ec_row34_col45, #T_e45ec_row34_col47, #T_e45ec_row35_col35, #T_e45ec_row36_col36, #T_e45ec_row37_col37, #T_e45ec_row38_col38, #T_e45ec_row38_col46, #T_e45ec_row39_col34, #T_e45ec_row39_col39, #T_e45ec_row39_col41, #T_e45ec_row39_col43, #T_e45ec_row39_col45, #T_e45ec_row39_col47, #T_e45ec_row40_col40, #T_e45ec_row41_col34, #T_e45ec_row41_col39, #T_e45ec_row41_col41, #T_e45ec_row41_col43, #T_e45ec_row41_col45, #T_e45ec_row41_col47, #T_e45ec_row42_col42, #T_e45ec_row43_col34, #T_e45ec_row43_col39, #T_e45ec_row43_col41, #T_e45ec_row43_col43, #T_e45ec_row43_col45, #T_e45ec_row43_col47, #T_e45ec_row44_col44, #T_e45ec_row45_col34, #T_e45ec_row45_col39, #T_e45ec_row45_col41, #T_e45ec_row45_col43, #T_e45ec_row45_col45, #T_e45ec_row45_col47, #T_e45ec_row46_col38, #T_e45ec_row46_col46, #T_e45ec_row47_col34, #T_e45ec_row47_col39, #T_e45ec_row47_col41, #T_e45ec_row47_col43, #T_e45ec_row47_col45, #T_e45ec_row47_col47 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e45ec_row0_col1, #T_e45ec_row7_col13, #T_e45ec_row10_col1, #T_e45ec_row12_col13, #T_e45ec_row27_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_e45ec_row0_col2, #T_e45ec_row0_col38, #T_e45ec_row0_col46, #T_e45ec_row1_col0, #T_e45ec_row5_col0, #T_e45ec_row11_col37, #T_e45ec_row13_col43, #T_e45ec_row13_col45, #T_e45ec_row13_col47, #T_e45ec_row19_col40, #T_e45ec_row22_col35, #T_e45ec_row28_col0, #T_e45ec_row28_col40, #T_e45ec_row32_col35, #T_e45ec_row34_col13, #T_e45ec_row39_col13, #T_e45ec_row41_col25 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_e45ec_row0_col3, #T_e45ec_row0_col28, #T_e45ec_row4_col22, #T_e45ec_row15_col42, #T_e45ec_row18_col34, #T_e45ec_row18_col39, #T_e45ec_row21_col45, #T_e45ec_row24_col45, #T_e45ec_row24_col47, #T_e45ec_row27_col41, #T_e45ec_row30_col34, #T_e45ec_row30_col39 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_e45ec_row0_col4, #T_e45ec_row1_col16, #T_e45ec_row1_col23, #T_e45ec_row3_col45, #T_e45ec_row3_col47, #T_e45ec_row4_col7, #T_e45ec_row4_col12, #T_e45ec_row4_col38, #T_e45ec_row4_col46, #T_e45ec_row5_col33, #T_e45ec_row5_col45, #T_e45ec_row5_col47, #T_e45ec_row10_col34, #T_e45ec_row10_col39, #T_e45ec_row10_col42, #T_e45ec_row13_col10, #T_e45ec_row26_col4, #T_e45ec_row35_col17, #T_e45ec_row35_col26, #T_e45ec_row37_col25, #T_e45ec_row40_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e45ec_row0_col5, #T_e45ec_row0_col6, #T_e45ec_row4_col0, #T_e45ec_row25_col37, #T_e45ec_row29_col5, #T_e45ec_row30_col1, #T_e45ec_row34_col5, #T_e45ec_row35_col4, #T_e45ec_row35_col19, #T_e45ec_row36_col32, #T_e45ec_row38_col4, #T_e45ec_row39_col5, #T_e45ec_row42_col28, #T_e45ec_row46_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e45ec_row0_col7, #T_e45ec_row0_col12, #T_e45ec_row4_col29, #T_e45ec_row13_col15, #T_e45ec_row23_col19, #T_e45ec_row44_col30 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_e45ec_row0_col8, #T_e45ec_row4_col33, #T_e45ec_row13_col11, #T_e45ec_row15_col13, #T_e45ec_row16_col1, #T_e45ec_row21_col37, #T_e45ec_row30_col37, #T_e45ec_row43_col3, #T_e45ec_row44_col26 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e45ec_row0_col9, #T_e45ec_row0_col48, #T_e45ec_row1_col9, #T_e45ec_row1_col48, #T_e45ec_row2_col9, #T_e45ec_row2_col48, #T_e45ec_row3_col9, #T_e45ec_row3_col48, #T_e45ec_row4_col9, #T_e45ec_row4_col48, #T_e45ec_row5_col9, #T_e45ec_row5_col48, #T_e45ec_row6_col9, #T_e45ec_row6_col48, #T_e45ec_row7_col9, #T_e45ec_row7_col48, #T_e45ec_row8_col9, #T_e45ec_row8_col48, #T_e45ec_row9_col0, #T_e45ec_row9_col1, #T_e45ec_row9_col2, #T_e45ec_row9_col3, #T_e45ec_row9_col4, #T_e45ec_row9_col5, #T_e45ec_row9_col6, #T_e45ec_row9_col7, #T_e45ec_row9_col8, #T_e45ec_row9_col9, #T_e45ec_row9_col10, #T_e45ec_row9_col11, #T_e45ec_row9_col12, #T_e45ec_row9_col13, #T_e45ec_row9_col14, #T_e45ec_row9_col15, #T_e45ec_row9_col16, #T_e45ec_row9_col17, #T_e45ec_row9_col18, #T_e45ec_row9_col19, #T_e45ec_row9_col20, #T_e45ec_row9_col21, #T_e45ec_row9_col22, #T_e45ec_row9_col23, #T_e45ec_row9_col24, #T_e45ec_row9_col25, #T_e45ec_row9_col26, #T_e45ec_row9_col27, #T_e45ec_row9_col28, #T_e45ec_row9_col29, #T_e45ec_row9_col30, #T_e45ec_row9_col31, #T_e45ec_row9_col32, #T_e45ec_row9_col33, #T_e45ec_row9_col34, #T_e45ec_row9_col35, #T_e45ec_row9_col36, #T_e45ec_row9_col37, #T_e45ec_row9_col38, #T_e45ec_row9_col39, #T_e45ec_row9_col40, #T_e45ec_row9_col41, #T_e45ec_row9_col42, #T_e45ec_row9_col43, #T_e45ec_row9_col44, #T_e45ec_row9_col45, #T_e45ec_row9_col46, #T_e45ec_row9_col47, #T_e45ec_row9_col48, #T_e45ec_row10_col9, #T_e45ec_row10_col48, #T_e45ec_row11_col9, #T_e45ec_row11_col48, #T_e45ec_row12_col9, #T_e45ec_row12_col48, #T_e45ec_row13_col9, #T_e45ec_row13_col48, #T_e45ec_row14_col9, #T_e45ec_row14_col48, #T_e45ec_row15_col9, #T_e45ec_row15_col48, #T_e45ec_row16_col9, #T_e45ec_row16_col48, #T_e45ec_row17_col9, #T_e45ec_row17_col48, #T_e45ec_row18_col9, #T_e45ec_row18_col48, #T_e45ec_row19_col9, #T_e45ec_row19_col48, #T_e45ec_row20_col9, #T_e45ec_row20_col48, #T_e45ec_row21_col9, #T_e45ec_row21_col48, #T_e45ec_row22_col9, #T_e45ec_row22_col48, #T_e45ec_row23_col9, #T_e45ec_row23_col48, #T_e45ec_row24_col9, #T_e45ec_row24_col48, #T_e45ec_row25_col9, #T_e45ec_row25_col48, #T_e45ec_row26_col9, #T_e45ec_row26_col48, #T_e45ec_row27_col9, #T_e45ec_row27_col48, #T_e45ec_row28_col9, #T_e45ec_row28_col48, #T_e45ec_row29_col9, #T_e45ec_row29_col48, #T_e45ec_row30_col9, #T_e45ec_row30_col48, #T_e45ec_row31_col9, #T_e45ec_row31_col48, #T_e45ec_row32_col9, #T_e45ec_row32_col48, #T_e45ec_row33_col9, #T_e45ec_row33_col48, #T_e45ec_row34_col9, #T_e45ec_row34_col48, #T_e45ec_row35_col9, #T_e45ec_row35_col48, #T_e45ec_row36_col9, #T_e45ec_row36_col48, #T_e45ec_row37_col9, #T_e45ec_row37_col48, #T_e45ec_row38_col9, #T_e45ec_row38_col48, #T_e45ec_row39_col9, #T_e45ec_row39_col48, #T_e45ec_row40_col9, #T_e45ec_row40_col48, #T_e45ec_row41_col9, #T_e45ec_row41_col48, #T_e45ec_row42_col9, #T_e45ec_row42_col48, #T_e45ec_row43_col9, #T_e45ec_row43_col48, #T_e45ec_row44_col9, #T_e45ec_row44_col48, #T_e45ec_row45_col9, #T_e45ec_row45_col48, #T_e45ec_row46_col9, #T_e45ec_row46_col48, #T_e45ec_row47_col9, #T_e45ec_row47_col48, #T_e45ec_row48_col0, #T_e45ec_row48_col1, #T_e45ec_row48_col2, #T_e45ec_row48_col3, #T_e45ec_row48_col4, #T_e45ec_row48_col5, #T_e45ec_row48_col6, #T_e45ec_row48_col7, #T_e45ec_row48_col8, #T_e45ec_row48_col9, #T_e45ec_row48_col10, #T_e45ec_row48_col11, #T_e45ec_row48_col12, #T_e45ec_row48_col13, #T_e45ec_row48_col14, #T_e45ec_row48_col15, #T_e45ec_row48_col16, #T_e45ec_row48_col17, #T_e45ec_row48_col18, #T_e45ec_row48_col19, #T_e45ec_row48_col20, #T_e45ec_row48_col21, #T_e45ec_row48_col22, #T_e45ec_row48_col23, #T_e45ec_row48_col24, #T_e45ec_row48_col25, #T_e45ec_row48_col26, #T_e45ec_row48_col27, #T_e45ec_row48_col28, #T_e45ec_row48_col29, #T_e45ec_row48_col30, #T_e45ec_row48_col31, #T_e45ec_row48_col32, #T_e45ec_row48_col33, #T_e45ec_row48_col34, #T_e45ec_row48_col35, #T_e45ec_row48_col36, #T_e45ec_row48_col37, #T_e45ec_row48_col38, #T_e45ec_row48_col39, #T_e45ec_row48_col40, #T_e45ec_row48_col41, #T_e45ec_row48_col42, #T_e45ec_row48_col43, #T_e45ec_row48_col44 ...

# %%
feature_names = rc.best_estimator_[0].get_feature_names_out()
feature_importances = rc.best_estimator_[-1].feature_importances_
fi = pd.DataFrame({'feature':feature_names, 'weight': feature_importances})
fi.feature = fi.feature.str[5:]
# fi['type'] = fi.feature.str[:3]

fi.sort_values(by='weight', ascending=False).head(50)
# Out:
#                 feature    weight
# 7463               firm  0.054635
# 9137             harvey  0.041164
# 18220               shh  0.032929
# 3899               come  0.027545
# 7639                fly  0.026115
# 5      more_than_6ratio  0.024185
# 22339             which  0.024103
# 9567             honest  0.023404
# 1      more_than_2ratio  0.020367
# 6401                eld  0.016603
# 22647             would  0.015323
# 18480              sing  0.015092
# 13930                no  0.014669
# 5979            downton  0.014647
# 634             america  0.014206
# 20014              talk  0.014157
# 18487           singing  0.014139
# 9536               home  0.014074
# 6253               east  0.013856
# 20840            travel  0.013303
# 20377             thief  0.012161
# 10797               job  0.012094
# 18293             shoot  0.012007
# 4990               date  0.011787
# 6404           elderman  0.011414
# 19049             spend  0.011264
# 2792                bye  0.011264
# 5383            destiny  0.011252
# 22396               why  0.010121
# 5804                doc  0.009638
# 7226              favor  0.009354
# 22188              weak  0.008964
# 22613              work  0.008772
# 19870              swim  0.008596
# 3308          charmaine  0.008465
# 20527              till  0.007600
# 6482                 em  0.007375
# 5127               deep  0.007319
# 9125              harry  0.006964
# 11132              kill  0.006929
# 3492               chop  0.006920
# 1707                bed  0.006655
# 22255              well  0.006442
# 18879          somebody  0.006414
# 21177                um  0.006318
# 13022              mine  0.006198
# 11111               kid  0.006177
# 9194               head  0.005670
# 18673              slow  0.005622
# 3144                 cb  0.005582

# %%
movies.groupby('level')[levels_ratio].median()
# Out:
#         A1ratio   A2ratio   B1ratio   B2ratio   C1ratio
# level
# A2     0.292737  0.166544  0.114264  0.113893  0.041701
# B1     0.289696  0.166092  0.115803  0.119832  0.041962
# B2     0.307146  0.168007  0.120994  0.126675  0.044762
# C1     0.314499  0.168517  0.125650  0.127029  0.042973

# %%
movies.groupby('level')[levels_ratio].median().plot()
plt.show()

# %%
oxford_words['length'] = oxford_words.word.str.len()

# %%
oxford_words.groupby('level').length.median().plot(kind='bar')
plt.title('Медианная длина слова в словаре Oxford')
plt.ylabel('Количество символов')
plt.xlabel('Уровень английского')
plt.show()

# %%
movies
# Out:
#      movie                                           filename  \
# 0      0.0            Crown, The S01E01 - Wolferton Splash.en
# 1      0.0                            Suits.Episode 1- Denial
# 2      0.0  Crazy4TV.com - Suits.S06E06.720p.BluRay.x265.H...
# 3      0.0                      Suits.S02E08.HDTV.x264-EVOLVE
# 4      0.0  Virgin.River.S01E07.INTERNAL.720p.WEB.x264-STRiFE
# ..     ...                                                ...
# 265    0.0                                      Matilda(1996)
# 266    0.0                                          Her(2013)
# 267    0.0                   The_Fundamentals_of_Caring(2016)
# 268    0.0                                   The_Intern(2015)
# 269    0.0                                      Aladdin(1992)
#
#                                                content level  \
# 0    seeking his british nationalization his royal ...    B2
# 1    you' the most amazing woman have ever met are ...    B2
# 2    ' been after sutter for three years now this g...    B2
# 3    you' late nope seconds early good learning tel...    B2
# 4    are you sure can' convince you stay you were r...    B2
# ..                                                 ...   ...
# 265  everyone born but not everyone born the same s...    B1
# 266  advertise your product brand here contact www ...    A2
# 267  caregiving not just about feeding and clothing...    B1
# 268  freud said love and work work and love that' a...    B2
# 269  come from land from faraway place where the ca...    A2
#
#                                                 lemmas   A1   A2   B1   B2  \
# 0    seek his british nationalization his royal hig...  232  132   96   86
# 1    you ' the most amazing woman have ever meet be...  280  144   96  100
# 2    ' be after sutter for three year now this guy ...  301  163  122  124
# 3    you ' late nope second early good learning tel...  292  134  106  116
# 4    be you sure can ' convince you stay you be rig...  249  123   82   91
# ..                                                 ...  ...  ...  ...  ...
# 265  everyone bear but not everyone bear the same s...  383  223  144  140
# 266  advertise your product brand here contact www ...  366  216  134  143
# 267  caregive not just about feeding and clothing a...  337  180  111  137
# 268  freud say love and work work and love that ' a...  407  270  178  183
# 269  come from land from faraway place where the ca...  304  202  147  147
#
#        C1  ...  less_than6  equal7  more_than7  less_than7  equal8  \
# 0    38.0  ...        2052     163         237        2277      87
# 1    33.0  ...        4872     222         268        5215     129
# 2    33.0  ...        5232     336         301        5632     143
# 3    22.0  ...        4244     228         192        4574      76
# 4    20.0  ...        3293     111         134        3480      64
# ..    ...  ...         ...     ...         ...         ...     ...
# 265  43.0  ...        5420     321         421        5906     172
# 266  49.0  ...        8038     356         580        8561     300
# 267  35.0  ...        5584     233         339        5949     178
# 268  58.0  ...       10275     407         664       10949     310
# 269  63.0  ...        5620     296         345        6162     197
#
#      more_than8  less_than8  equal9  more_than9  less_than9
# 0           150        2440      77          73        2527
# 1           139        5437      71          68        5566
# 2           158        5968      90          68        6111
# 3           116        4802      70          46        4878
# 4            70        3591      42          28        3655
# ..          ...         ...     ...         ...         ...
# 265         249        6227     111         138        6399
# 266         280        8917     125         155        9217
# 267         161        6182      80          81        6360
# 268         354       11356     186         168       11666
# 269         148        6458      76          72        6655
#
# [270 rows x 57 columns]
